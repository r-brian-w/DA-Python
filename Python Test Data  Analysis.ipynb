# %% [markdown]
# # Import function

# %%
# Data Analysis using csv, pandas, numpy, and matplotlib
# csv for load csv file
# pandas for column, database, table
# numpy for numeric, math
# mathplotlib for design, data visualization

# %%
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Import CSV

# %%
# load csv

with open('dailyActivity_merged.csv') as csv_file:
    csv_read=csv.reader(csv_file, delimiter=',')

# %%
# make csv to table
# sometime using df as dataframe

data = pd.read_csv('dailyActivity_merged.csv')
data.head() # to display the first 5 lines of loaded data
# Out:
#            Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 0  1503960366    4/12/2016       13162           8.50             8.50
# 1  1503960366    4/13/2016       10735           6.97             6.97
# 2  1503960366    4/14/2016       10460           6.74             6.74
# 3  1503960366    4/15/2016        9762           6.28             6.28
# 4  1503960366    4/16/2016       12669           8.16             8.16
#
#    LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 0                       0.0                1.88                      0.55
# 1                       0.0                1.57                      0.69
# 2                       0.0                2.44                      0.40
# 3                       0.0                2.14                      1.26
# 4                       0.0                2.71                      0.41
#
#    LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# ...

# %% [markdown]
# # Checking information of Table, Database

# %%
# Information of table or database

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 863 entries, 0 to 862
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             863 non-null    string
#  1   ActivityDate   863 non-null    datetime64[ns]
#  2   TotalSteps     863 non-null    int64
#  3   TotalDistance  863 non-null    float64
#  4   Calories       863 non-null    int64
#  5   TotalMinutes   863 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(3), string(1)
# memory usage: 40.6 KB

# %%
# always check for total number of rows
# type data for each column

# %% [markdown]
# # Checking NaN, or null values

# %%
# check if there null value in dataframe / table 
# True = there null
# false = not have null value

data.isnull().values.any()
# Out:
# False

# %%
# sum null data in table
data.isnull().sum().sum()
# Out:
# 0

# %%
# if want to use column
# function same as looking as table

df['your column name'].isnull().values.any()

# %%
df['your column name'].isnull().sum()

# %%
# Retrieve number of non-NA values

data.count()
# Out:
# Id                          940
# ActivityDate                940
# TotalSteps                  940
# TotalDistance               940
# TrackerDistance             940
# LoggedActivitiesDistance    940
# VeryActiveDistance          940
# ModeratelyActiveDistance    940
# LightActiveDistance         940
# SedentaryActiveDistance     940
# VeryActiveMinutes           940
# FairlyActiveMinutes         940
# LightlyActiveMinutes        940
# SedentaryMinutes            940
# Calories                    940
# dtype: int64

# %%
data.isna().sum().sum()
# Out:
# 0

# %% [markdown]
# # Check for duplicate

# %%
#identify duplicate rows
duplicateRows = data[data.duplicated()]

#view duplicate rows
duplicateRows
# Out:
# Empty DataFrame
# Columns: [Id, ActivityDate, TotalSteps, TotalDistance, TrackerDistance, LoggedActivitiesDistance, VeryActiveDistance, ModeratelyActiveDistance, LightActiveDistance, SedentaryActiveDistance, VeryActiveMinutes, FairlyActiveMinutes, LightlyActiveMinutes, SedentaryMinutes, Calories]
# Index: []

# %%
# Delete duplicate
# inplace = True have function for implement result directly to table

data.drop_duplicates(inplace=True)

# %% [markdown]
# # Check math formula for each column

# %%
# Formula to check are count, mean, min, max, std,

# %%
data.describe()
# Out:
#          TotalSteps  TotalDistance     Calories  TotalMinutes
# count    863.000000     863.000000   863.000000    863.000000
# mean    8319.392816       5.979513  2361.295481   1203.559676
# std     4744.967224       3.721044   702.711148    263.198571
# min        4.000000       0.000000    52.000000      2.000000
# 25%     4923.000000       3.370000  1855.500000    983.500000
# 50%     8053.000000       5.590000  2220.000000   1353.000000
# 75%    11092.500000       7.900000  2832.000000   1440.000000
# max    36019.000000      28.030001  4900.000000   1440.000000

# %%
data.memory_usage()
# Out:
# Index                        128
# Id                          7520
# ActivityDate                7520
# TotalSteps                  7520
# TotalDistance               7520
# TrackerDistance             7520
# LoggedActivitiesDistance    7520
# VeryActiveDistance          7520
# ModeratelyActiveDistance    7520
# LightActiveDistance         7520
# SedentaryActiveDistance     7520
# VeryActiveMinutes           7520
# FairlyActiveMinutes         7520
# LightlyActiveMinutes        7520
# SedentaryMinutes            7520
# Calories                    7520
# dtype: int64

# %% [markdown]
# # Convert data type

# %%
# Converting data type
data['Id'] = data.Id.astype('string')

# %%
data['ActivityDate'] = pd.to_datetime(data['ActivityDate'])

# %%
# check for unique value in ID column
data.Id.unique()
# Out:
# <StringArray>
# ['1503960366', '1624580081', '1644430081', '1844505072', '1927972279',
#  '2022484408', '2026352035', '2320127002', '2347167796', '2873212765',
#  '3372868164', '3977333714', '4020332650', '4057192912', '4319703577',
#  '4388161847', '4445114986', '4558609924', '4702921684', '5553957443',
#  '5577150313', '6117666160', '6290855005', '6775888955', '6962181067',
#  '7007744171', '7086361926', '8053475328', '8253242879', '8378563200',
#  '8583815059', '8792009665', '8877689391']
# Length: 33, dtype: string

# %%
data.Id.value_counts()
# Out:
# 1503960366    31
# 4388161847    31
# 2022484408    31
# 1844505072    31
# 2026352035    31
# 4020332650    31
# 4319703577    31
# 2873212765    31
# 1927972279    31
# 8877689391    31
# 4445114986    31
# 2320127002    31
# 1624580081    31
# 4558609924    31
# 4702921684    31
# 5553957443    31
# 6962181067    31
# 7086361926    31
# 8053475328    31
# 8378563200    31
# 8583815059    31
# 5577150313    30
# 1644430081    30
# 3977333714    30
# 8792009665    29
# 6290855005    29
# 6117666160    28
# 6775888955    26
# 7007744171    26
# 3372868164    20
# 8253242879    19
# 2347167796    18
# 4057192912     4
# Name: Id, dtype: Int64

# %% [markdown]
# # Analyze Data

# %%
data = data.drop(columns=['CaloriesMean'])

# %%
data['TotalMinutes1'] = data[['VeryActiveMinutes','FairlyActiveMinutes','LightlyActiveMinutes','SedentaryMinutes']].sum(1)

# %%
data['TotalMinutes'] = data['TotalMinutes']

# %%
data
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  Calories  \
# 560  6117666160   2016-04-21       19542          15.01      4900
# 531  5577150313   2016-04-17       12231           9.14      4552
# 836  8877689391   2016-04-16       29326          25.29      4547
# 545  5577150313   2016-05-01       13368           9.99      4546
# 544  5577150313   2016-04-30       12363           9.24      4501
# ..          ...          ...         ...            ...       ...
# 648  6962181067   2016-05-12        3587           2.37       928
# 525  5553957443   2016-05-12        3121           2.04       741
# 239  2347167796   2016-04-29          42           0.03       403
# 371  4319703577   2016-05-12          17           0.01       257
# 320  3977333714   2016-05-11         746           0.50        52
#
#      TotalMinutes
# 560           903
# 531           921
# 836          1440
# 545           943
# 544          1036
# ..            ...
# 648           240
# ...

# %%
data.Calories.value_counts().
# Out:
# 1980    13
# 2063    11
# 1841     9
# 1688     9
# 1347     8
#         ..
# 52       1
# 3654     1
# 1981     1
# 2011     1
# 1849     1
# Name: Calories, Length: 734, dtype: int64

# %%
CaloriesMean = data.groupby(['Id'])['Calories'].mean()
CaloriesMean
# Out:
# Id
# 1503960366    1816.419355
# 1624580081    1483.354839
# 1644430081    2811.300000
# 1844505072    1573.483871
# 1927972279    2172.806452
# 2022484408    2509.967742
# 2026352035    1540.645161
# 2320127002    1724.161290
# 2347167796    2043.444444
# 2873212765    1916.967742
# 3372868164    1933.100000
# 3977333714    1513.666667
# 4020332650    2385.806452
# 4057192912    1973.750000
# 4319703577    2037.677419
# 4388161847    3093.870968
# 4445114986    2186.193548
# 4558609924    2033.258065
# 4702921684    2965.548387
# 5553957443    1875.677419
# 5577150313    3359.633333
# 6117666160    2261.142857
# 6290855005    2599.620690
# 6775888955    2131.769231
# 6962181067    1982.032258
# 7007744171    2544.000000
# 7086361926    2566.354839
# 8053475328    2945.806452
# 8253242879    1788.000000
# 8378563200    3436.580645
# 8583815059    2732.032258
# 8792009665    1962.310345
# 8877689391    3420.258065
# Name: Calories, dtype: float64

# %%
CaloriesMean.min(axis=0)
# Out:
# 1483.3548387096773

# %%
print(CaloriesMean == CaloriesMean.min())
# Out:
# Id
# 1503960366    False
# 1624580081     True
# 1644430081    False
# 1844505072    False
# 1927972279    False
# 2022484408    False
# 2026352035    False
# 2320127002    False
# 2347167796    False
# 2873212765    False
# 3372868164    False
# 3977333714    False
# 4020332650    False
# 4057192912    False
# 4319703577    False
# 4388161847    False
# 4445114986    False
# 4558609924    False
# 4702921684    False
# 5553957443    False
# 5577150313    False
# 6117666160    False
# 6290855005    False
# 6775888955    False
# 6962181067    False
# 7007744171    False
# 7086361926    False
# 8053475328    False
# 8253242879    False
# 8378563200    False
# 8583815059    False
# 8792009665    False
# 8877689391    False
# Name: Calories, dtype: bool

# %%
data.groupby(['Id'])['Calories'].mean().max()
# Out:
# 3436.5806451612902

# %%
print(data[data.Calories == data.Calories.max()])
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  TrackerDistance  \
# 606  6117666160   2016-04-21       19542          15.01            15.01
#
#      LoggedActivitiesDistance  VeryActiveDistance  ModeratelyActiveDistance  \
# 606                       0.0                0.98                       0.4
#
#      LightActiveDistance  SedentaryActiveDistance  VeryActiveMinutes  \
# 606                 5.62                      0.0                 11
#
#      FairlyActiveMinutes  LightlyActiveMinutes  SedentaryMinutes  Calories  \
# 606                   19                   294               579      4900
#
#      CaloriesMean
# 606           NaN

# %%
print(data[data.Calories == data.Calories.min()])
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  Calories  \
# 320  3977333714   2016-05-11         746            0.5        52
#
#      TotalMinutes
# 320            26

# %%
print(data[((data.Calories == data.Calories.min()) & (data.Calories > 0))])
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  Calories  \
# 320  3977333714   2016-05-11         746            0.5        52
#
#      TotalMinutes
# 320            26

# %%
print(data.max())
# Out:
# Id                        8877689391
# ActivityDate     2016-05-12 00:00:00
# TotalSteps                     36019
# TotalDistance                  28.03
# Calories                        4900
# TotalMinutes                    1440
# dtype: object

# %%
Id = data['Id']
Calories = data['Calories']
 
# Figure Size
fig = plt.figure(figsize =(10, 7))
 
# Horizontal Bar Plot
plt.bar(Id, Calories)
plt.xlabel("Id")
plt.xticks(rotation=90)
plt.ylabel("Calories")

# Show Plot
# Out:
# Text(0, 0.5, 'Calories')

# %%
print('Calories paling sedikit adalah', Calories.min(), 'kalori')
print('Calories paling banyak adalah', Calories.max(), 'kalori')
print('Calories rerata adalah', Calories.mean(), 'kalori')
# Out:
# Calories paling sedikit adalah 52 kalori
# Calories paling banyak adalah 4900 kalori
# Calories rerata adalah 2361.295480880649 kalori

# %%
CaloriesMean = data.groupby(['Id'])['Calories'].mean(1)
print(CaloriesMean)
# Out:
# Id
# 1503960366    1876.966667
# 1624580081    1483.354839
# 1644430081    2811.300000
# 1844505072    1713.761905
# 1927972279    2303.058824
# 2022484408    2509.967742
# 2026352035    1540.645161
# 2320127002    1724.161290
# 2347167796    2043.444444
# 2873212765    1916.967742
# 3372868164    1933.100000
# 3977333714    1513.666667
# 4020332650    2719.941176
# 4057192912    2039.666667
# 4319703577    2037.677419
# 4388161847    3093.870968
# 4445114986    2186.193548
# 4558609924    2033.258065
# 4702921684    2997.166667
# 5553957443    1875.677419
# 5577150313    3469.678571
# 6117666160    2427.434783
# 6290855005    2772.708333
# 6775888955    2285.705882
# 6962181067    1982.032258
# 7007744171    2686.125000
# 7086361926    2597.600000
# 8053475328    2945.806452
# 8253242879    1887.333333
# 8378563200    3436.580645
# 8583815059    2823.100000
# 8792009665    2192.526316
# 8877689391    3420.258065
# Name: Calories, dtype: float64

# %%
data.groupby(['Id'])['Calories'].mean(1)
# Out:
# Id
# 1503960366    1876.966667
# 1624580081    1483.354839
# 1644430081    2811.300000
# 1844505072    1713.761905
# 1927972279    2303.058824
# 2022484408    2509.967742
# 2026352035    1540.645161
# 2320127002    1724.161290
# 2347167796    2043.444444
# 2873212765    1916.967742
# 3372868164    1933.100000
# 3977333714    1513.666667
# 4020332650    2719.941176
# 4057192912    2039.666667
# 4319703577    2037.677419
# 4388161847    3093.870968
# 4445114986    2186.193548
# 4558609924    2033.258065
# 4702921684    2997.166667
# 5553957443    1875.677419
# 5577150313    3469.678571
# 6117666160    2427.434783
# 6290855005    2772.708333
# 6775888955    2285.705882
# 6962181067    1982.032258
# 7007744171    2686.125000
# 7086361926    2597.600000
# 8053475328    2945.806452
# 8253242879    1887.333333
# 8378563200    3436.580645
# 8583815059    2823.100000
# 8792009665    2192.526316
# 8877689391    3420.258065
# Name: Calories, dtype: float64

# %%
data['CaloriesMean'] = CaloriesMean
data['CaloriesMean']
# Out:
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN
#        ..
# 858   NaN
# 859   NaN
# 860   NaN
# 861   NaN
# 862   NaN
# Name: CaloriesMean, Length: 863, dtype: float64

# %%
data
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  Calories  \
# 0    1503960366   2016-04-12       13162           8.50      1985
# 1    1503960366   2016-04-13       10735           6.97      1797
# 2    1503960366   2016-04-14       10460           6.74      1776
# 3    1503960366   2016-04-15        9762           6.28      1745
# 4    1503960366   2016-04-16       12669           8.16      1863
# ..          ...          ...         ...            ...       ...
# 858  8877689391   2016-05-08       10686           8.11      2847
# 859  8877689391   2016-05-09       20226          18.25      3710
# 860  8877689391   2016-05-10       10733           8.15      2832
# 861  8877689391   2016-05-11       21420          19.56      3832
# 862  8877689391   2016-05-12        8064           6.12      1849
#
#      TotalMinutes  CaloriesMean
# 0            1094           NaN
# 1            1033           NaN
# 2            1440           NaN
# 3             998           NaN
# ...

# %% [markdown]
# # Sorting Function

# %%
# Sort by Calories Columns
# inplace is for aplly directly to data
# safe for using false

data.sort_values(by='Calories', ascending=False, inplace=True)
data.head()
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  Calories  \
# 560  6117666160   2016-04-21       19542          15.01      4900
# 531  5577150313   2016-04-17       12231           9.14      4552
# 836  8877689391   2016-04-16       29326          25.29      4547
# 545  5577150313   2016-05-01       13368           9.99      4546
# 544  5577150313   2016-04-30       12363           9.24      4501
#
#      TotalMinutes
# 560           903
# 531           921
# 836          1440
# 545           943
# 544          1036

# %% [markdown]
# # Plot / Data Visualization

# %%
data.plot(x='')

# %%
plt.hist(data["Calories"])
plt.show()

# %%
print("Line graph: ")
plt.plot(data["Calories"], data["TotalSteps"])
plt.show()
# Out:
# Line graph:

# %%
Id = data['Id'].head(2)
Calories = data['Calories'].head(2)
 
# Figure Size
fig = plt.figure(figsize =(10, 7))
 
# Horizontal Bar Plot
plt.bar(Id, Calories)
plt.xlabel("Id")
plt.ylabel("Calories")

# Show Plot
plt.show()

# %%
x = [1,2,3,4,5,-1-2]
y = [-1,5, 100, -2, 50, 100]
t = [100, 110, 120, 130, 140, 150]
plt.figure()

ax1 = plt.subplot(3, 1, 1)
plt.title('Demo');
ax1.plot(t,x, 'b.:', label="Demo") # Showing top Horizontal 
plt.legend()

ax2 = plt.subplot(3, 1, 2, sharex=ax1)
ax2.plot(t,y, 'b.:', label="Demo1") # Not showing up
plt.legend()

ax3 = plt.subplot(3, 1, 3, sharex=ax1)
ax3.plot(t,t, 'b.:', label="Demo2") # This is perfect how I wanted
plt.legend()
plt.show()

# %%
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330])

plt.plot(x, y)

plt.xlabel("Average Pulse")
plt.ylabel("Calorie Burnage")

plt.show()

# %% [markdown]
# # Random / Unsorted

# %%
# Shows all rows and column with more than 0 values

data[data.TotalSteps > 0]
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  Calories  \
# 0    1503960366   2016-04-12       13162       8.500000      1985
# 1    1503960366   2016-04-13       10735       6.970000      1797
# 2    1503960366   2016-04-14       10460       6.740000      1776
# 3    1503960366   2016-04-15        9762       6.280000      1745
# 4    1503960366   2016-04-16       12669       8.160000      1863
# ..          ...          ...         ...            ...       ...
# 935  8877689391   2016-05-08       10686       8.110000      2847
# 936  8877689391   2016-05-09       20226      18.250000      3710
# 937  8877689391   2016-05-10       10733       8.150000      2832
# 938  8877689391   2016-05-11       21420      19.559999      3832
# 939  8877689391   2016-05-12        8064       6.120000      1849
#
#      TotalMinutes
# 0            1094
# 1            1033
# 2            1440
# 3             998
# 4            1040
# ..            ...
# 935          1440
# ...

# %%
# Apply to dataframe

data = data[data.TotalSteps > 0]

# %%
# Reset Index after manipulation data
# reset index add index columns
# Need to drop / delete it

data.reset_index(inplace = True, drop = True)

# %%
# Rounding all decimal to 2 zero

data.round(2)

# use this to aplly to data
#data = data.round(2)

# %%
# For view all rows

with pd.option_context('display.max_rows', None,):
   print(data)
# Out:
#              Id ActivityDate  TotalSteps  TotalDistance  Calories  \
# 560  6117666160   2016-04-21       19542          15.01      4900
# 531  5577150313   2016-04-17       12231           9.14      4552
# 836  8877689391   2016-04-16       29326          25.29      4547
# 545  5577150313   2016-05-01       13368           9.99      4546
# 544  5577150313   2016-04-30       12363           9.24      4501
# 850  8877689391   2016-04-30       27745          26.72      4398
# 538  5577150313   2016-04-24       15764          11.78      4392
# 530  5577150313   2016-04-16       14269          10.66      4274
# 761  8378563200   2016-04-21       15148          12.01      4236
# 754  8378563200   2016-04-14       13318          10.56      4163
# 758  8378563200   2016-04-18       13630          10.81      4157
# 857  8877689391   2016-05-07       12332           8.13      4142
# 759  8378563200   2016-04-19       13070          10.36      4092
# ...

# %% [markdown]
# # Save file to csv

# %%
# saving the DataFrame as a CSV file

csv_data = data.to_csv('Activity_Merged_Edited.csv', index = True)
